# %% [markdown]
# __<font size="8">IMDB Movie Clustering and Genre <br /><br /> Classification<br /></font>__
# <br />
# <br />
# <font size="5">Thinkful Data Science<br /></font>
# <br />
# <font size="5">Marshall Mamiya Unsupervised Learning Capstone</font>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Dataset-Information" data-toc-modified-id="Dataset-Information-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dataset Information</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Cleaning</a></span><ul class="toc-item"><li><span><a href="#Null-Values" data-toc-modified-id="Null-Values-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Null Values</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Outliers</a></span></li></ul></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Word-Embedding" data-toc-modified-id="Word-Embedding-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Word Embedding</a></span></li><li><span><a href="#Target-Variable:-Key-Genre" data-toc-modified-id="Target-Variable:-Key-Genre-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Target Variable: Key Genre</a></span></li><li><span><a href="#One-Hot-Encoded-Words" data-toc-modified-id="One-Hot-Encoded-Words-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>One-Hot Encoded Words</a></span></li></ul></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Clustering</a></span><ul class="toc-item"><li><span><a href="#Investigate-Clusters" data-toc-modified-id="Investigate-Clusters-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Investigate Clusters</a></span></li><li><span><a href="#K-Means-Clusters" data-toc-modified-id="K-Means-Clusters-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>K-Means Clusters</a></span></li></ul></li><li><span><a href="#Supervised-Modeling" data-toc-modified-id="Supervised-Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Supervised Modeling</a></span></li><li><span><a href="#Evaluate-Best-Model" data-toc-modified-id="Evaluate-Best-Model-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Evaluate Best Model</a></span></li><li><span><a href="#Supervised-vs.-Unsupervised-Performance" data-toc-modified-id="Supervised-vs.-Unsupervised-Performance-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Supervised vs. Unsupervised Performance</a></span></li><li><span><a href="#Application-and-End-User-Value" data-toc-modified-id="Application-and-End-User-Value-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Application and End User Value</a></span></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# For your third capstone, you’ll complete an unsupervised learning project. You can choose your own research question or choose from one below.
#
# How do you achieve the following using clustering techniques?
#
# Netflix wants to identify similar movies based on movie characteristics.
# A company wants to segment its customers.
# Your startup is creating an innovative new email software. How can you help them to create an effective spam filter?
# Your chief marketing officer wants to know how much website traffic is due to spam and bots versus actual customers. How can you group the traffic?
# Your spouse loves fantasy baseball and has a few favorite players. How can you help them to choose who to have on their team?
# Security team in a bank wants to identify fraudulent transactional activities.
# Next steps:
#
# Go out and find a dataset of interest. It could be one that helps you work on one of our recommended research questions, or any other dataset that addresses an unsupervised learning question of your own.
#
# Explore the data. Get to know the data. Spend a lot of time going over its quirks and peccadilloes. You should understand how it was gathered, what's in it, and what the variables look like.
#
# You should try several different approaches and really work to tune a variety of models before choosing what you consider to be the best performer.
#
# Things to keep in mind: how do clustering and modeling compare? What are the advantages of each? Why would you want to use one over the other?
#
# This will ultimately include the following deliverables:
#
# A Jupyter notebook that tells a compelling story about your data (to be submitted at the end of this checkpoint).
# A 15 to 30 minute presentation of your findings. You'll need to produce a deck and present it to the Thinkful community.
# Conduct the analysis in Jupyter. Provide a complete research report using the framework introduced in the previous module. The report should include compelling visualizations and actionable insights, telling the story to your intended audience. Walk through the analysis using clean, reproducible code. Include plenty of notes and comments to guide others through your thinking.
#
# Rather than create a deck in a presentation tool like PowerPoint or Google Slides, we will use Jupyter’s built-in slide deck capabilities. This cuts down on the time-consuming and error-prone process of copying-and-pasting into an external program. The presentation is also fully reproducible.
#
# On the day of your presentation, an evaluator from the Thinkful educator team will introduce you, and then you'll give your presentation. Afterward, the evaluator will ask you follow up questions and will grade your performance on your presentation. Members of the audience will also be encouraged to ask follow up questions.
#
# Be prepared to talk about:
#
# Your end-user and the value your project provides to them.
# Quantifiable results based on the research you’ve conducted.
# The visuals you chose and what they represent for your research.
# Next steps you'd take to expand on your work.
# A specified research question your model addresses.
# How you chose your model specification and what alternatives you compared it to.
# The practical uses of your model for an audience of interest.
# Any weak points or shortcomings of your model.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
import string
from datetime import datetime


from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, silhouette_score
from scipy.stats import ttest_ind
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
from nltk.corpus import stopwords 
from scipy.stats.mstats import winsorize


from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn import ensemble
from sklearn.neural_network import MLPClassifier
import time
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AffinityPropagation
from sklearn import metrics
from sklearn.svm import SVC
from yellowbrick.cluster import KElbowVisualizer

from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di 

# %matplotlib inline

# Options for pandas
pd.options.display.max_columns = 150
pd.options.display.max_rows = 150

# %%
#toggle code for jupyter slideshow 
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
df = pd.read_csv('data/IMDB-Movie-Data.csv')

# %% [markdown]
# # Dataset Information
#
# [Dataset](https://www.kaggle.com/PromptCloudHQ/imdb-data) contains 1,000 IMDB top movies between 2006-2016. Features include: Rank, Title, Genre, Description, Director, Actors, Year, Runtime, Rating, Votes, Revenue, and Metascore.

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Null Values

# %%
df.isnull().sum()/df.isnull().count()*100
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
#mean imputation for each respective null feature

df['Revenue (Millions)'].fillna(df['Revenue (Millions)'].mean(), inplace=True)
df['Metascore'].fillna(df['Metascore'].mean(), inplace=True)

# %% [markdown]
# ## Outliers

# %% [markdown]
# - Revenue and votes columns have outliers
# - Large difference between their respective 75th percentile and max value

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)    Metascore
# count         1000.000000  1000.000000
# mean            82.956376    58.985043
# std             96.412043    16.634858
# min              0.000000    11.000000
# 25%             17.442500    47.750000
# ...

# %%
outlier_cols = ['Revenue (Millions)', 'Votes']
for col in outlier_cols:
    q25, q75 = np.percentile(df[col], [25,75])
    iqr = q75 - q25
    min_val = q25 - iqr
    max_val = q75 + iqr


    min_outliers, max_outliers = len(np.where(df[col] < min_val)[0]), len(np.where(df[col] > max_val)[0])
    min_pct, max_pct = min_outliers/len(df), max_outliers/len(df)
    df['winsorized_'+col] = winsorize(df[col], (min_pct, max_pct))
    max_val = df[col].max()
    max_cap_val = df['winsorized_'+col].max()
    
    print()
    print(col)
    print()
    print('Min Outliers: ', min_outliers)
    print('Max Outliers: ', max_outliers)
    print('Max Original: ', max_val)
    print('Max Capped: ', max_cap_val)
# Out:
# Revenue (Millions)
#
# Min Outliers:  0
# Max Outliers:  113
# Max Original:  936.63
# Max Capped:  180.19
#
# Votes
#
# Min Outliers:  0
# Max Outliers:  84
# Max Original:  1791916
# Max Capped:  442082

# %% [markdown]
# # Data Exploration

# %% [markdown]
# - Postive correlation between votes and revenue (.52), runtime and rating (.39), votes and rating, rating and metascore (.60)
# - Negative correlation between votes and rating (-.48)

# %%
x_features = ['winsorized_Revenue (Millions)', 'Year', 'Rating', 'winsorized_Votes', 'Metascore', 'Runtime (Minutes)']

df[x_features].corr()
# Out:
#                                winsorized_Revenue (Millions)      Year  \
# winsorized_Revenue (Millions)                       1.000000 -0.154914
# Year                                               -0.154914  1.000000
# Rating                                              0.142274 -0.211219
# winsorized_Votes                                    0.591303 -0.475901
# Metascore                                           0.091925 -0.076077
# Runtime (Minutes)                                   0.212940 -0.164900
#
#                                  Rating  winsorized_Votes  Metascore  \
# winsorized_Revenue (Millions)  0.142274          0.591303   0.091925
# Year                          -0.211219         -0.475901  -0.076077
# Rating                         1.000000          0.520904   0.604723
# winsorized_Votes               0.520904          1.000000   0.325111
# Metascore                      0.604723          0.325111   1.000000
# ...

# %% [markdown]
# - Skewed left distribution for year
# - Skewed right distribution for votes

# %%
g = plt.figure(figsize=(.25,.25))
g = sns.PairGrid(df[x_features])
g = g.map_lower(sns.kdeplot, shade=True)
g = g.map_upper(sns.kdeplot, shade=True)
g = g.map_diag(plt.hist, edgecolor="w")


plt.show()
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# - Genre will be the supervised classication target variable
# - Genre feature contains multi-genre list for some movies
# - Multi-genres have to be broken down into one key genre or be removed for classication
# - Challenging for a classifier to differentiate the difference between action vs. action, adventure, drama

# %%
df['Genre'].value_counts()
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Action,Adventure,Fantasy      27
# Animation,Adventure,Comedy    27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Biography,Drama,History       14
# Biography,Drama               14
# Adventure,Family,Fantasy      14
# Action,Adventure,Comedy       14
# Action,Comedy,Crime           12
# Action,Crime,Thriller         12
# Horror                        11
# Action,Adventure,Thriller     11
# Crime,Drama                   10
# Thriller                       9
# Action,Thriller                9
# Animation,Action,Adventure     9
# Biography,Crime,Drama          9
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Word Embedding

# %% [markdown]
# Convert movie descriptions into word embeddings
#    - Lowercase
#    - Split at spaces
#    - Remove punctuations and stops words
#    - Filter out words that have a total count of less than five within the entire dataset description word count
#    - Transform into word vectors (vector length = 100)
#    - Final vector is the average of all word vectors for each respective movie

# %%
df['word_list'] = df['Description'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)).strip().lower().split())

stop_words = list(stopwords.words())

def remove_stopwords(word_list):
    filtered_word_list = [word for word in word_list if word not in stop_words]
    return filtered_word_list

df['clean_word_list'] = df['word_list'].apply(remove_stopwords)

word_embeddings = Word2Vec(df['clean_word_list'].tolist(), min_count=5)

# %%
word_embeddings.wv.similar_by_word('fight')
# Out:
# [('family', 0.8599876165390015),
#  ('life', 0.8423022627830505),
#  ('city', 0.8366079330444336),
#  ('world', 0.8362960815429688),
#  ('one', 0.8228112459182739),
#  ('finds', 0.8219823837280273),
#  ('discover', 0.8215155601501465),
#  ('young', 0.8211908340454102),
#  ('new', 0.8205591440200806),
#  ('love', 0.8196533918380737)]

# %%
def vector_funct(word_list):
    filter_word_list = [word for word in word_list if word in word_embeddings]
    if len(filter_word_list) != 0:
        return sum([word_embeddings.wv[word] for word in filter_word_list ]) / len(filter_word_list)
    else:
        return np.zeros(100)


df['vector'] = df['clean_word_list'].apply(vector_funct)
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).

# %% [markdown]
# ## Target Variable: Key Genre

# %%
def get_key_genre(genre_list):
    genre_list = genre_list.split(',')
    key_genre_list = [genre for genre in genre_list if genre in key_genre]
    if len(key_genre_list) == 1:
        return key_genre_list[0]
    
    elif len(key_genre_list) > 1:
        return 'multiple'
    
    else:
        return 'NA'
            

df['Genre'].value_counts()
key_genre = ['Action', 'Drama', 'Comedy']

df['key_genre'] = df['Genre'].apply(get_key_genre)
df['key_genre'].value_counts()
# Out:
# Drama       342
# multiple    215
# Action      187
# Comedy      135
# NA          121
# Name: key_genre, dtype: int64

# %% [markdown]
# - Action movies have higher revenue and votes
# - Drama movies have higher ratings and metascore
# - Majority of movies come out around 2014-2016

# %%
plt.figure(figsize=(13,8))
for i,col in enumerate(x_features):
    plt.subplot(2,3,i+1)
    sns.violinplot(x='key_genre', y=x_features[i], data=df)
    
plt.tight_layout()
plt.show()
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## One-Hot Encoded Words

# %% [markdown]
# - Collect top five most frequent description words within each key genre
# - If that genre's frequent word count is twice the count of another key genre then that words will be an one-hot encoded feature

# %%
#get all clean words from description column
all_words = [word for word_list in df['clean_word_list'] for word in word_list]

#get frequency of words
all_words_dict = dict(Counter(all_words))

genre_list = list(df['key_genre'].unique())

top_genre_word_dict = {}
genre_word_dict = {}
dummy_words = []

for genre in genre_list:
    
    #get all words within genre
    genre_words = [word for word_list in df['clean_word_list'][df['key_genre'] == genre] for word in word_list]
    genre_word_dict[genre] = dict(Counter(genre_words))
    
    #get top 5 most frequent words within respective genre
    top_genre_words = dict(Counter(genre_words).most_common()[:20])
    
    #add top words to genre_word_dict
    top_genre_word_dict[genre] = top_genre_words
    
    
    x_genre = genre
    #get list of other genre for ratios
    other_genres = [genre for genre in genre_list if genre != x_genre]
    for word in top_genre_word_dict[x_genre].keys():
        for genre in other_genres:
            try:
                other_genre_freq = genre_word_dict[genre][word]
            except KeyError:
                other_genre_freq = 0
            
            x_genre_freq = top_genre_word_dict[x_genre][word]
            
            ratio = other_genre_freq / x_genre_freq
            if ratio < .9:
                dummy_words.append(word)
                
dummy_words = list(np.unique(dummy_words))

# %%
df = df.reset_index(drop=True)

# %%
dummy_cols = []

for word in dummy_words:
    df['DV_'+word] = 0
    dummy_cols.append('DV_'+word)
for i,word_list in enumerate(df['clean_word_list']):
    for word in dummy_words:
        if word in word_list:
            df.at[i, 'DV_'+word] = 1
        else: 
            df.at[i, 'DV_'+word] = 0

# %%
# Description Length Feature

df['description_len'] = df['word_list'].apply(lambda x: len(x))

# %% [markdown]
# # Clustering

# %% [markdown]
# Separate supervised data from unsupervised data
#
# Supervised Data:
#     - Explanatory include continous variables, dummy variables and word embeddings
#     - Movies with multiple key genres are filtered out
#
# Unsupervised data:
#     - Explanatory include continous variables, dummy variables and word embeddings
#     - Includes movies that fall under multiple key genres since clustering based on genres isn't explicit in unsupervised models and more data the better

# %%
standard_s = StandardScaler()

continous_features = ['winsorized_Revenue (Millions)', 'winsorized_Votes', 'Rating', 'Metascore', 'Runtime (Minutes)']

cluster_vectors = np.vstack((df['vector']))
cluster_feature_df = df[dummy_cols + continous_features]
cluster_data = np.hstack((cluster_vectors, cluster_feature_df))

cluster_normalize_data = standard_s.fit_transform(cluster_data)

classification_df = df[df['key_genre']!= 'multiple'].copy()
classification_feature_df = classification_df[dummy_cols + continous_features]
classification_vectors = np.vstack((classification_df['vector']))
classification_data = np.hstack((classification_vectors, classification_feature_df))

classification_normalize_data = standard_s.fit_transform(classification_data)

# %%
km = KMeans()
ke = KElbowVisualizer(km, k=(2,20))
ke.fit(cluster_normalize_data)
ke.show()
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
km = KMeans(n_clusters=11, random_state=42)
km_pred = km.fit_predict(cluster_normalize_data)
clusters = km.cluster_centers_

# %%
bandwidth = estimate_bandwidth(cluster_normalize_data)
ms = MeanShift(bandwidth=bandwidth, cluster_all=True).fit(cluster_normalize_data)
ms_clusters = len(ms.cluster_centers_)
ms_pred = ms.labels_

print('Bandwidth: ', bandwidth)
print('N Clusters: ', ms_clusters)
# Out:
# Bandwidth:  15.91384670646718
# N Clusters:  14

# %%
sc = SpectralClustering(n_clusters=11)

sc_pred = sc.fit_predict(cluster_normalize_data)
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/cluster/spectral.py:268: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (11). Possibly due to duplicate points in X.
#   n_init=n_init)

# %%
ap = AffinityPropagation(damping=.5)

ap_pred = ap.fit_predict(cluster_normalize_data)

# Pull the number of clusters and cluster assignments for each data point.
cluster_centers_indices = ap.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)


print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Estimated number of clusters: 83

# %%
tsne = TSNE(n_components=2, n_iter=500)
tsne_results = tsne.fit_transform(cluster_normalize_data)

# %%
def plot_tsne_clusters(ap_pred, sc_pred, ms_pred, km_pred, tsne_results, skip_ap=False):
    plt.figure(figsize=(12,8))

    if skip_ap == True:
        plt.subplot(2,2,1)
        plt.title('Spectral')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=sc_pred, alpha=.5)

        plt.subplot(2,2,2)
        plt.title('Mean Shift')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=ms_pred, alpha=.5)

        plt.subplot(2,2,3)
        plt.title('K-Means')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=km_pred, alpha=.5)
    
    else:
        plt.subplot(2,2,1)
        plt.title('Affinity Propagation')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=ap_pred, alpha=.5)

        plt.subplot(2,2,2)
        plt.title('Spectral')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=sc_pred, alpha=.5)

        plt.subplot(2,2,3)
        plt.title('Mean Shift')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=ms_pred, alpha=.5)

        plt.subplot(2,2,4)
        plt.title('K-Means')
        plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=km_pred, alpha=.5)

    plt.tight_layout()
    plt.show()

# %%
plot_tsne_clusters(ap_pred, sc_pred, ms_pred, km_pred, tsne_results)

# %%
pd.crosstab(km_pred, df['key_genre'], margins=True)
# Out:
# key_genre  Action  Comedy  Drama   NA  multiple   All
# row_0
# 0              14      11     25    7        25    82
# 1              12       4     19    5        11    51
# 2              38      35     61   20        44   198
# 3              28      35     50   27        35   175
# 4               7       5     18    6         5    41
# 5               2       9      1    2         8    22
# 6               2       4     29    7        11    53
# 7              52      17     84   28        47   228
# 8              21       9     19    4        12    65
# 9               2       2     11    4         4    23
# 10              9       4     25   11        13    62
# All           187     135    342  121       215  1000

# %% [markdown]
# - Cluster assignments somewhat represent the key genre feature
# - K-Means clusterd the best
# - Bigger clusters have more variance in regards to key genres
# - Clustering with only continous and one-hot encoded words created distinct clusters but no useful information
# - Clustering with only word vectors creatd one big blob

# %%
df['km_clusters'] = km_pred

# %% [markdown]
# ## Investigate Clusters

# %%
#gets cluster count, top 3 genres and top 5 words within each cluster

def cluster_info(cluster_col, df):
    for cluster in list(df[cluster_col].value_counts().keys()):
            cluster_df = df[df[cluster_col] == cluster]
            cluster_words = [word for word_list in cluster_df['clean_word_list'] for word in word_list]
            genre_list = [genre for genre_list in cluster_df['Genre'].value_counts().keys().tolist() for genre in genre_list.split(',')]
            top_genres = Counter(genre_list).most_common()[:3]

            print()
            print('Cluster', cluster)
            print('Cluster Count: ', len(cluster_df))
            print('Top 3 Genres: \n', top_genres)
            print()
            print('Top 5 most frequent words: \n', Counter(cluster_words).most_common()[:5])

# %% [markdown]
# ## K-Means Clusters

# %% [markdown]
# - Majority of clusters share similar averages for continous features
# - Significant difference between cluster's average for one-hot encoded words

# %%
df.groupby('km_clusters').mean()
# Out:
#                    Rank         Year  Runtime (Minutes)    Rating  \
# km_clusters
# 0            424.333333  2012.666667         109.142857  6.795238
# 1            488.152104  2012.624595         116.016181  6.807443
# 2            421.098361  2013.065574         122.081967  6.883607
# 3            533.560000  2011.960000         108.120000  6.752000
# 4            487.712121  2012.060606         117.469697  7.040909
# 5            468.812500  2012.656250         110.625000  6.425000
# 6            526.468750  2012.312500         119.218750  6.884375
# 7            541.989247  2013.096774         112.172043  6.751613
# 8            521.677903  2013.089888         109.093633  6.526592
# 9            543.444444  2013.000000         107.402778  6.658333
# 10           402.954545  2012.545455         112.727273  6.718182
#
#                      Votes  Revenue (Millions)  Metascore  \
# km_clusters
# 0            236103.523810          141.779524  63.952381
# ...

# %%
cluster_info('km_clusters', df)
# Out:
# Cluster 1
# Cluster Count:  309
# Top 3 Genres:
#  [('Drama', 59), ('Action', 42), ('Adventure', 31)]
#
# Top 5 most frequent words:
#  [('two', 24), ('story', 18), ('friends', 15), ('woman', 15), ('american', 14)]
#
# Cluster 8
# Cluster Count:  267
# Top 3 Genres:
#  [('Drama', 43), ('Action', 32), ('Comedy', 29)]
#
# Top 5 most frequent words:
#  [('new', 38), ('life', 35), ('must', 25), ('family', 25), ('one', 22)]
#
# Cluster 7
# Cluster Count:  93
# Top 3 Genres:
#  [('Drama', 25), ('Comedy', 16), ('Thriller', 14)]
#
# Top 5 most frequent words:
#  [('life', 43), ('new', 27), ('two', 24), ('family', 19), ('young', 18)]
#
# Cluster 9
# Cluster Count:  72
# Top 3 Genres:
#  [('Drama', 32), ('Action', 16), ('Thriller', 13)]
#
# Top 5 most frequent words:
#  [('young', 70), ('woman', 24), ('home', 10), ('years', 9), ('mysterious', 8)]
#
# Cluster 4
# Cluster Count:  66
# Top 3 Genres:
#  [('Drama', 23), ('Action', 16), ('Adventure', 11)]
#
# Top 5 most frequent words:
# ...

# %% [markdown]
# Example Cluster
#
# Cluster 10:
#     - High revenue action movies
#     - Top words reflect the definition of action movies

# %%
df[df['km_clusters']==10]
# Out:
#      Rank                                       Title  \
# 0       1                     Guardians of the Galaxy
# 50     51  Star Wars: Episode VII - The Force Awakens
# 76     77                                The Avengers
# 79     80                                Ghostbusters
# 91     92                                    Warcraft
# 94     95                     Avengers: Age of Ultron
# 133   134                                    Whiplash
# 150   151                                     The BFG
# 205   206                              X: First Class
# 269   270                                     Satanic
# 323   324                                     In Time
# 384   385                              The Lego Movie
# 432   433                                 World War Z
# 496   497                              Men in Black 3
# 575   576                         Clash of the Titans
# 581   582                          The Last Airbender
# ...

# %% [markdown]
# # Supervised Modeling

# %% [markdown]
# Grid Search CV uses the dictionary of hyperparameters to return the best combination of hyperparameters for each model.

# %%
rfc = RandomForestClassifier()
rfc.parameters = {'criterion':('gini', 'entropy'), 'n_estimators':[5,10,20,40], 
                  'max_depth': [1,2,4,8,16,32], 'min_samples_leaf': [1,2,4,8]}

dt = DecisionTreeClassifier()
dt.parameters = {'criterion':('gini', 'entropy'), 'max_depth': [1,2,4,8,16,32], 'min_samples_leaf': [1,2,4,8]}

knn = KNeighborsClassifier()
knn.parameters = {'weights':('uniform', 'distance'), 'n_neighbors':[1,2,4,8]}

mlp = MLPClassifier()
mlp.parameters = {'hidden_layer_sizes':[10,15,20], 'activation':('relu', 'logistic'), 
              'learning_rate': ('constant', 'adaptive')}

gb = GradientBoostingClassifier()
gb.parameters = {'learning_rate': [.001,.01, .1], 'criterion': ('friedman_mse', 'mae')}


model_dict = {'rfc': rfc, 'mlp':mlp, 'knn':knn, 'dt': dt}

# %%
for name, model in model_dict.items():
    clf = GridSearchCV(model, model.parameters, cv=5, scoring='accuracy')
    if name in ['mlp', 'knn']:
        clf.fit(classification_normalize_data, classification_df['key_genre'])
    else:
        clf.fit(classification_data, classification_df['key_genre'])

    model_dict[name] = clf.best_estimator_
model_dict
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
for name,model in model_dict.items():
    if name in ['knn', 'mlp']:
        train_x, test_x, train_y, test_y = train_test_split(classification_normalize_data, classification_df['key_genre'], test_size=.3)
    else:
        train_x, test_x, train_y, test_y = train_test_split(classification_data, classification_df['key_genre'], test_size=.3)
    
    start = time.time()
    model.fit(train_x, train_y)
    end = time.time()
    train_score = model.score(train_x, train_y) * 100
    score = model.score(test_x, test_y) * 100
    if  name == 'rfc':
        importances = model.feature_importances_
    
    print()
    print(name)
    print('Runtime: ', end - start)
    print('Train Accuracy: ', train_score)
    print('Test Accuracy: ', score)
# Out:
# rfc
# Runtime:  0.13196086883544922
# Train Accuracy:  100.0
# Test Accuracy:  50.0
#
# mlp
# Runtime:  0.5731358528137207
# Train Accuracy:  85.79234972677595
# Test Accuracy:  54.66101694915254
#
# knn
# Runtime:  0.002956867218017578
# Train Accuracy:  55.19125683060109
# Test Accuracy:  54.23728813559322
#
# dt
# Runtime:  0.02427816390991211
# Train Accuracy:  63.20582877959927
# Test Accuracy:  50.847457627118644
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# # Evaluate Best Model

# %% [markdown]
# - Key genre distribution is bias towards Drama
# - Base accuracy of 43.6% by just guessing Drama
# - Training with MLP increased accuracy by 14% (+/- .06)

# %%
scores = cross_val_score(model_dict['mlp'], classification_normalize_data, classification_df['key_genre'], scoring='accuracy', cv=5)

print('dt')
print("AUC: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/marshallmamiya/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
classification_df['key_genre'].value_counts()/len(classification_df)*100
# Out:
# Drama     43.566879
# Action    23.821656
# Comedy    17.197452
# NA        15.414013
# Name: key_genre, dtype: float64

# %% [markdown]
# # Supervised vs. Unsupervised Performance

# %% [markdown]
# Unsupervised:
# - The K-Means model clusterd movies more by the qualitative features than quantitative features
# - Most clusters had similar averages and std in relation to quantitative features - except higher std features like revenue and votes
# - Clustering reflected key genre when words within description relate to genre (e.g. action: fight, heroes, world)
# - More insightful in conveying information about the dataset than supervised learning
#
# Supervised:
# - Poor accuracy for predicting key genres
# - Performed poorly when also trained with just quantitative features and just word vectors
# - Could be improved with more data

# %% [markdown]
# # Application and End User Value

# %% [markdown]
# Clustering:
#    - Movie recommendations (e.g. if a user watches a movie from cluster two then the recommnedation system could recommend other movies from cluster two
#    - Recommending movies with high revenue and votes
#    - Recommend movies by key words (e.g. love, fight, New York, etc.)
#
# Modeling:
#    - With current data there is not a valuable end user product
#    - A better approach would be to predict revenue or rating of movies using regression techniques
