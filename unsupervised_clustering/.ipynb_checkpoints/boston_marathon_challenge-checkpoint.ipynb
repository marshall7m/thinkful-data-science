# %% [markdown]
# # Introduction

# %% [markdown]
# There is a lot of information on runners and their performance for the Boston Marathon. Pick a year (post-2012 has more info) and do some clustering.
#
# Specifically, use the tools at hand to determine which clustering solution, including number of clusters and algorithm used, is best for the marathon data. Once you have a solution you like, write a data story, including visualizations, where you teach the reader something about the Boston Marathon based on your clusters.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
# %matplotlib inline

# Options for pandas
pd.options.display.max_columns = 150
pd.options.display.max_rows = 150

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Imports</a></span></li></ul></li></ul></li><li><span><a href="#Mean-Shift" data-toc-modified-id="Mean-Shift-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Mean Shift</a></span></li><li><span><a href="#mentor-question" data-toc-modified-id="mentor-question-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>mentor question</a></span></li></ul></div>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/llimllib/bostonmarathon/master/results/2014/results.csv')

# %%
df.head()

# %%
df.describe()

# %%
df.isnull().sum() / df.isnull().count()

# %%
df.dropna(subset=['city'], inplace=True)
#drop observations with '-' in time columns
df = df[(df['5k'] != '-') & (df['10k'] != '-') & (df['20k'] != '-') & (df['25k'] != '-') & (df['30k'] != '-') & (df['35k'] != '-') & (df['40k'] != '-') & (df['half'] != '-')]


#use only numerical and one-hot encoded gender columns for modeling

feature_list = [col for col in df.columns if col not in ['name', 'bib', 'ctz', 'state', 'country', 'gender', 'city']]

#convert time columns to float
for col in feature_list:
    if df[col].dtypes == 'object':
        try:
            df[col] = df[col].astype('float')
        except TypeError:
            continue
        except ValueError:
            continue
            
feature_df = df[feature_list]
feature_df = pd.merge(feature_df, pd.get_dummies(df['gender']), left_index=True, right_index=True)

# %% [markdown]
# After a failed attempt to cluster the

# %%
feature_df.head()
# Out:
#      10k  division    25k  age  official  genderdiv     35k  overall  pace  \
# 0  17.37         8  47.67   47     85.25          8   71.40        8  3.27
# 1  32.58         1  82.43   33    138.95          1  116.37       21  5.30
# 2  16.62         1  45.80   41     80.60          1   67.42        1  3.08
# 3  32.57         3  82.43   24    140.58          3  116.37       27  5.37
# 4  17.12         2  46.37   40     81.23          2   67.83        2  3.10
#
#      30k     5k   half    20k     40k  F  M  percentile_label
# 0  59.18   8.02  39.72  37.65   80.43  0  1                 0
# 1  99.33  16.22  69.47  65.83  132.10  1  0                 0
# 2  56.45   7.75  38.03  36.10   76.10  0  1                 0
# 3  99.33  16.20  69.47  65.83  132.95  1  0                 0
# 4  57.03   8.02  38.60  36.58   76.72  0  1                 0

# %% [markdown]
# Let's train a K-Means model using only two clusters. I'm predicting that the clusters will group the data by gender. Although I am quite skeptical about my prediction since my intuition says that both genders in lower ranking division probably overlap in times and there's only a clear distinction between genders in higher ranking groups.

# %%
data = normalize(feature_df.loc[:, feature_df.columns.isin(['F', 'M']) == False])

data = PCA(2).fit_transform(data)

y_pred = KMeans(n_clusters=2, random_state=42).fit_predict(data)

print(pd.crosstab(feature_df['M'], y_pred))

num_rows = (len(feature_list) * 2) / 2
for i,col in enumerate(feature_list):
    plt.figure(figsize=(20,25))
    plt.subplot(num_rows, 2, i+1)
    plt.scatter(feature_df['40k'], feature_df[col], c=feature_df['M'], alpha=.3)
    plt.xlabel('40k')
    plt.ylabel(col)
    plt.title('Gender Clusters')
    plt.subplots_adjust(hspace=.9)
    
    plt.subplot(num_rows, 2, i+2)
    plt.scatter(feature_df['40k'], feature_df[col], c=y_pred, alpha=.3)
    plt.xlabel('40k')
    plt.ylabel(col)
    plt.title('K-Means Clusters')
    plt.subplots_adjust(hspace=.9)
    plt.tight_layout()
    plt.show()
# Out:
# col_0      0     1
# M
# 0      14130    34
# 1       8004  9480

# %% [markdown]
# We gave the K-means model quite a challenge. The true gender plots show that there's defianlty not a clear distinction between genders. It seems like the K-Means clusters instead grouped observations by their distance times. For example in the 40k vs 10k K-means plot, the yellow group 40k times were roughly below 220 minutes and their respective 10k times were below 160 minutes. Anything observations with times above those two thresholds were labeled under the purple group.

# %% [markdown]
# In order the evaluate how well K-Means clusters observations by distance times, we have to map distance times to cateogorical labels. For this attempt we will just map the 40k times to the percentile they fall under.

# %%
def percentile_label(x):
    if x < np.percentile(feature_df['40k'],25):
        return 0
    elif (x > np.percentile(feature_df['40k'],25)) & (x < np.percentile(feature_df['40k'],50)):
        return 1
    elif (x > np.percentile(feature_df['40k'],50)) & (x < np.percentile(feature_df['40k'],75)):
        return 2
    else:
        return 3

# %%
#create new label that categorizes the person's 40k time by percentile
feature_df['percentile_label'] = feature_df['40k'].apply(lambda x:percentile_label(x))

# %%
feature_df['percentile_label'].value_counts()
# Out:
# 3    7921
# 2    7911
# 0    7909
# 1    7907
# Name: percentile_label, dtype: int64

# %%
data = normalize(feature_df.loc[:, feature_df.columns != 'percentile_label'])

data = PCA(2).fit_transform(data)

# 4 percentile labels
y_pred = KMeans(n_clusters=4, random_state=42).fit_predict(data)

print(pd.crosstab(feature_df['percentile_label'], y_pred))

num_rows = (len(feature_list) * 2) / 2
for i,col in enumerate(feature_list):
    plt.figure(figsize=(20,40))
    plt.subplot(num_rows, 2, i+1)
    plt.scatter(feature_df[col], feature_df['40k'], c=feature_df['percentile_label'], alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('40k Percentile Clusters')
    plt.subplots_adjust(hspace=.9)
    
    plt.subplot(num_rows, 2, i+2)
    plt.scatter(feature_df[col], feature_df['40k'], c=y_pred, alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('K-Means Clusters')
    plt.subplots_adjust(hspace=.9)
    plt.tight_layout()
    plt.show()
# Out:
# col_0                0     1     2    3
# percentile_label
# 0                 1370  3098  3015  426
# 1                 4140    39  3728    0
# 2                 4450     0  3461    0
# 3                 4166     1  3754    0

# %% [markdown]
# The K-Means model correctly labels observations as less than the 25th percentile if the 40k time is less than 150 minutes. A bulk of observations were mislabeled as less than the 25th percentile even though there respective true 40k times were not. The reason could be because of bad initial centroid placement or feature similarity between each clusters.
#
# Looking at the true percentile plots above, there are a few features where clusters overlap. Features with large variances and/or low correlation with 40k within a true cluster (percentile) group are likely to have unintentional similarity with other clusters. These features include:
#
#     - Division
#     - Gender Divison
#     - Overall
#     - Age
#     - 5K
#
# The similarity in clusters could be caused by the fact that K-Means randomly initializes it's cluster. The clusters could of been randomly initialized too close to each other which caused them to share points. Using K-Means shift could possibly help with this similarity problem. K-Means shift initializes it's clusters at different modes. The points moves to the closest cluster instead of the cluster moving towards the mean of the closest points.

# %% [markdown]
# # Mean Shift

# %%
bandwidth = estimate_bandwidth(feature_df[feature_list], quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=3735, bin_seeding=True)

ms.fit(feature_df.loc[:, feature_df.columns != 'percentile_label'])

# Extract cluster assignments for each data point.
labels = ms.labels_

# Coordinates of the cluster centers.
cluster_centers = ms.cluster_centers_

# Count our clusters.
n_clusters_ = len(np.unique(labels))
print('Bandwidth: ', 3735)
print("Number of estimated clusters: {}".format(n_clusters_))
print(pd.crosstab(feature_df['percentile_label'],labels))
print('Accuracy: ', accuracy_score(feature_df['percentile_label'],labels)*100)
num_rows = (len(feature_list) * 2) / 2
for i,col in enumerate(feature_list):
    plt.figure(figsize=(20,40))
    plt.subplot(num_rows, 2, i+1)
    plt.scatter(feature_df[col], feature_df['40k'], c=feature_df['percentile_label'], alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('40k Percentile Clusters')
    
    plt.subplot(num_rows, 2, i+2)
    plt.scatter(feature_df[col], feature_df['40k'], c=labels, alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('K-Means Shift')
    plt.tight_layout()
    plt.show()
# Out:
# Bandwidth:  3735
# Number of estimated clusters: 4
# col_0                0     1     2     3
# percentile_label
# 0                 7460     3     0   446
# 1                  179   860     0  6868
# 2                    0  6884   440   587
# 3                    4   401  7512     4
# Accuracy:  27.692113245702732

# %% [markdown]
# # mentor question
#
# why does the plot not accurately represent the accuracy score?

# %% [markdown]
# Comparing the percentile labeled plots to the K-Means shift plots, we can see that the K-Means shift did a pretty good job compared to K-Means. Using the estimate_bandwith function, the estimated bandwith was very large (bandwith=5261) causing the estimated number of clusters to be three. After manually tweaking the bandwith, I was able to get the number of estimated clusters to represent the four percentile labels.

# %%
from sklearn.cluster import SpectralClustering

n_clusters=4

sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(feature_df.loc[:, feature_df.columns != 'percentile_label'].sample(frac=.25))

predict=sc.fit_predict(feature_df.loc[:, feature_df.columns != 'percentile_label'])

for i,col in enumerate(feature_list):
    plt.figure(figsize=(20,40))
    plt.subplot(num_rows, 2, i+1)
    plt.scatter(feature_df[col], feature_df['40k'], c=feature_df['percentile_label'], alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('40k Percentile Clusters')
    
    plt.subplot(num_rows, 2, i+2)
    plt.scatter(feature_df[col], feature_df['40k'], c=predict, alpha=.3)
    plt.xlabel(col)
    plt.ylabel('40k')
    plt.title('K-Means Shift')
    plt.tight_layout()
    plt.show()

# %%
from sklearn.cluster import AffinityPropagation
from sklearn import metrics

# Declare the model and fit it in one statement.
# Note that you can provide arguments to the model, but we didn't.
af = AffinityPropagation().fit(X_train)
print('Done')

# Pull the number of clusters and cluster assignments for each data point.
cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))

# %%
from itertools import cycle

plt.figure(1)
plt.clf()

# Cycle through each cluster and graph them with a center point for the
# exemplar and lines from the exemplar to each data point in the cluster.
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()
